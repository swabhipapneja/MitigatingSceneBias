# %%
import os
import json
import torch
from torchvision.models.detection import maskrcnn_resnet50_fpn
from torchvision.transforms import functional as F
from PIL import Image
import numpy as np
from time import time
from torch.cuda.amp import autocast
from torch.utils.data import DataLoader, Dataset

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load the pretrained Mask R-CNN model
model = maskrcnn_resnet50_fpn(pretrained=True)
model = model.to(device)  # Move the model to GPU
model.eval()  # Set the model to evaluation mode


def save_image_paths_to_json(input_dir, json_path):
    """
    Traverse the input directory and save all image paths to a JSON file.
    """
    all_images = []
    for root, _, files in os.walk(input_dir):
        for file in sorted(files):  # Ensure consistent order
            if file.lower().endswith((".jpg", ".jpeg", ".png")):
                all_images.append(os.path.join(root, file))
    with open(json_path, 'w') as json_file:
        json.dump(all_images, json_file)
    print(f"Saved {len(all_images)} image paths to {json_path}")


def load_image_paths_from_json(json_path):
    """
    Load image paths from a JSON file.
    """
    if not os.path.exists(json_path):
        raise FileNotFoundError(f"JSON file not found: {json_path}")
    with open(json_path, 'r') as json_file:
        all_images = json.load(json_file)
    print(f"Loaded {len(all_images)} image paths from {json_path}")
    return all_images


def filter_images_by_directory(image_paths):
    """
    Filter the image paths to consider only up to 16 images per directory.
    """
    filtered_images = []
    dir_to_images = {}

    # Group images by their parent directory
    for image_path in image_paths:
        directory = os.path.dirname(image_path)
        if directory not in dir_to_images:
            dir_to_images[directory] = []
        dir_to_images[directory].append(image_path)

    # Filter images within each directory
    for directory, images in dir_to_images.items():
        # Sort images to ensure the correct order (frame_0000, frame_0001, ...)
        sorted_images = sorted(images)
        filtered_images.extend(sorted_images[:16])  # Take only the first 16 images

    return filtered_images


def mask_humans(image, predictions, threshold=0.5, original_size=None):
    """
    Mask human figures in the input image and restore to original size if specified.
    """
    image_array = np.array(image)
    masks = predictions['masks']
    labels = predictions['labels']
    scores = predictions['scores']

    for i in range(len(masks)):
        if labels[i] == 1 and scores[i] > threshold:  # Label 1 in COCO is "person"
            binary_mask = masks[i, 0].cpu().numpy() > 0.5
            binary_mask = Image.fromarray(binary_mask).resize(
                (image_array.shape[1], image_array.shape[0]), Image.NEAREST
            )
            binary_mask = np.array(binary_mask)
            image_array[binary_mask] = [255, 255, 255]

    masked_image = Image.fromarray(image_array)
    if original_size:
        masked_image = masked_image.resize(original_size, Image.ANTIALIAS)
    return masked_image


class ImageDataset(Dataset):
    """
    Custom Dataset for loading images and resizing.
    """
    def __init__(self, image_paths, resize_to):
        self.image_paths = image_paths
        self.resize_to = resize_to

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        path = self.image_paths[idx]
        try:
            image = Image.open(path).convert("RGB")
            original_size = image.size
            image_resized = image.resize((self.resize_to, self.resize_to), Image.ANTIALIAS)
            return F.to_tensor(image_resized), original_size, path
        except Exception as e:
            print(f"Error loading image: {path}, skipping. Error: {e}")
            return None


def custom_collate_fn(batch):
    """
    Custom collate function to handle None values in DataLoader.
    """
    batch = [item for item in batch if item is not None]  # Filter out None values
    images, original_sizes, paths = zip(*batch)
    return torch.stack(images), original_sizes, paths


def process_and_mask_images(input_dir, json_path, output_dir, batch_size=4, threshold=0.5, resize_to=800, num_workers=4):
    """
    Process images using CPU for preprocessing and GPU for inference.
    """
    if not os.path.exists(json_path):
        save_image_paths_to_json(input_dir, json_path)
    
    all_images = load_image_paths_from_json(json_path)
    filtered_images = filter_images_by_directory(all_images)
    dataset = ImageDataset(filtered_images, resize_to)
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        num_workers=num_workers,  # Use multiple CPU workers for preprocessing
        pin_memory=True,
        collate_fn=custom_collate_fn
    )

    start_time = time()
    processed_images = 0
    total_images = len(filtered_images)

    for images, original_sizes, paths in dataloader:
        images = images.to(device)  # Move batch to GPU
        with autocast():  # Mixed precision inference
            with torch.no_grad():
                predictions = model(images)

        for path, preds, original_size in zip(paths, predictions, original_sizes):
            original_image = Image.open(path).convert("RGB")
            masked_image = mask_humans(original_image, preds, threshold, original_size=original_size)

            relative_path = os.path.relpath(path, input_dir)
            output_path = os.path.join(output_dir, relative_path)
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            masked_image.save(output_path)

        processed_images += len(paths)
        elapsed_time = time() - start_time
        images_per_minute = (processed_images / elapsed_time) * 60
        remaining_images = total_images - processed_images
        eta = remaining_images / images_per_minute

        print(
            f"Processed {processed_images}/{total_images} images "
            f"({(processed_images / total_images) * 100:.2f}%). "
            f"Speed: {images_per_minute:.2f} images/min. ETA: {eta:.2f} minutes."
        )

    torch.cuda.empty_cache()


# Set paths for input, output, and JSON
input_directory = "/scratch/supalami/ProjectDataSplitwise/extracted_frames_mk_val_videos"
json_file_path = "/scratch/supalami/ProjectDataSplitwise/image_paths_validation.json"
output_directory = "/scratch/supalami/ProjectDataSplitwise/masked_extracted_frames_validation"

# Process and mask images using GPU for inference and CPU for preprocessing
process_and_mask_images(
    input_directory,
    json_file_path,
    output_directory,
    batch_size=120,
    threshold=0.5,
    resize_to=256,
    num_workers=os.cpu_count()  # Use all available CPU cores
)
# Out:
# Using device: cuda
# /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=MaskRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=MaskRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loaded 752031 image paths from /scratch/supalami/ProjectDataSplitwise/image_paths_validation.json
# /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages/torch/utils/data/dataloader.py:563: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Processed 120/64728 images (0.19%). Speed: 256.36 images/min. ETA: 252.02 minutes.
# Processed 240/64728 images (0.37%). Speed: 441.78 images/min. ETA: 145.97 minutes.
# Processed 360/64728 images (0.56%). Speed: 586.33 images/min. ETA: 109.78 minutes.
# Processed 480/64728 images (0.74%). Speed: 703.77 images/min. ETA: 91.29 minutes.
# Processed 600/64728 images (0.93%). Speed: 804.66 images/min. ETA: 79.70 minutes.
# Processed 720/64728 images (1.11%). Speed: 886.36 images/min. ETA: 72.21 minutes.
# Processed 840/64728 images (1.30%). Speed: 942.49 images/min. ETA: 67.79 minutes.
# Processed 960/64728 images (1.48%). Speed: 988.12 images/min. ETA: 64.53 minutes.
# Processed 1080/64728 images (1.67%). Speed: 1033.10 images/min. ETA: 61.61 minutes.
# Processed 1200/64728 images (1.85%). Speed: 1078.74 images/min. ETA: 58.89 minutes.
# Processed 1320/64728 images (2.04%). Speed: 1122.04 images/min. ETA: 56.51 minutes.
# Processed 1440/64728 images (2.22%). Speed: 1155.06 images/min. ETA: 54.79 minutes.
# Processed 1560/64728 images (2.41%). Speed: 1191.06 images/min. ETA: 53.04 minutes.
# Processed 1680/64728 images (2.60%). Speed: 1217.57 images/min. ETA: 51.78 minutes.
# Processed 6000/64728 images (9.27%). Speed: 1497.89 images/min. ETA: 39.21 minutes.
# Processed 6120/64728 images (9.45%). Speed: 1497.45 images/min. ETA: 39.14 minutes.
# Processed 6240/64728 images (9.64%). Speed: 1499.41 images/min. ETA: 39.01 minutes.
# Processed 6360/64728 images (9.83%). Speed: 1503.70 images/min. ETA: 38.82 minutes.
# Processed 6480/64728 images (10.01%). Speed: 1503.33 images/min. ETA: 38.75 minutes.
# Processed 6600/64728 images (10.20%). Speed: 1501.65 images/min. ETA: 38.71 minutes.
# Processed 6720/64728 images (10.38%). Speed: 1505.89 images/min. ETA: 38.52 minutes.
# Processed 6840/64728 images (10.57%). Speed: 1505.62 images/min. ETA: 38.45 minutes.
# Processed 6960/64728 images (10.75%). Speed: 1509.82 images/min. ETA: 38.26 minutes.
# Processed 7080/64728 images (10.94%). Speed: 1515.57 images/min. ETA: 38.04 minutes.
# Processed 7200/64728 images (11.12%). Speed: 1515.48 images/min. ETA: 37.96 minutes.
# Processed 7320/64728 images (11.31%). Speed: 1515.64 images/min. ETA: 37.88 minutes.
# Processed 7440/64728 images (11.49%). Speed: 1516.67 images/min. ETA: 37.77 minutes.
# Processed 7560/64728 images (11.68%). Speed: 1513.12 images/min. ETA: 37.78 minutes.
# Processed 7680/64728 images (11.87%). Speed: 1515.73 images/min. ETA: 37.64 minutes.
# Processed 7800/64728 images (12.05%). Speed: 1514.68 images/min. ETA: 37.58 minutes.
# Processed 7920/64728 images (12.24%). Speed: 1514.50 images/min. ETA: 37.51 minutes.
# Processed 8040/64728 images (12.42%). Speed: 1514.60 images/min. ETA: 37.43 minutes.
# Processed 8160/64728 images (12.61%). Speed: 1513.45 images/min. ETA: 37.38 minutes.
# Processed 8280/64728 images (12.79%). Speed: 1513.33 images/min. ETA: 37.30 minutes.
# Processed 8400/64728 images (12.98%). Speed: 1511.88 images/min. ETA: 37.26 minutes.
# Processed 8520/64728 images (13.16%). Speed: 1512.73 images/min. ETA: 37.16 minutes.
# Processed 8640/64728 images (13.35%). Speed: 1514.97 images/min. ETA: 37.02 minutes.
# Processed 8760/64728 images (13.53%). Speed: 1509.38 images/min. ETA: 37.08 minutes.
# Processed 8880/64728 images (13.72%). Speed: 1510.40 images/min. ETA: 36.98 minutes.
# Processed 9000/64728 images (13.90%). Speed: 1512.36 images/min. ETA: 36.85 minutes.
# Processed 9120/64728 images (14.09%). Speed: 1514.22 images/min. ETA: 36.72 minutes.
# Processed 9240/64728 images (14.28%). Speed: 1514.82 images/min. ETA: 36.63 minutes.
# Processed 9360/64728 images (14.46%). Speed: 1517.50 images/min. ETA: 36.49 minutes.
# Processed 9480/64728 images (14.65%). Speed: 1518.53 images/min. ETA: 36.38 minutes.
# Processed 9600/64728 images (14.83%). Speed: 1515.65 images/min. ETA: 36.37 minutes.
# Processed 9720/64728 images (15.02%). Speed: 1514.91 images/min. ETA: 36.31 minutes.
# Processed 9840/64728 images (15.20%). Speed: 1515.41 images/min. ETA: 36.22 minutes.
# Processed 9960/64728 images (15.39%). Speed: 1512.48 images/min. ETA: 36.21 minutes.
# Processed 18240/64728 images (28.18%). Speed: 1538.49 images/min. ETA: 30.22 minutes.
# Processed 18360/64728 images (28.36%). Speed: 1538.48 images/min. ETA: 30.14 minutes.
# Processed 18480/64728 images (28.55%). Speed: 1536.92 images/min. ETA: 30.09 minutes.
# Processed 18600/64728 images (28.74%). Speed: 1536.60 images/min. ETA: 30.02 minutes.
# Processed 18720/64728 images (28.92%). Speed: 1535.86 images/min. ETA: 29.96 minutes.
# Processed 18840/64728 images (29.11%). Speed: 1536.84 images/min. ETA: 29.86 minutes.
# Processed 18960/64728 images (29.29%). Speed: 1534.36 images/min. ETA: 29.83 minutes.
# Processed 19080/64728 images (29.48%). Speed: 1535.58 images/min. ETA: 29.73 minutes.
# Processed 19200/64728 images (29.66%). Speed: 1535.65 images/min. ETA: 29.65 minutes.
# Processed 19320/64728 images (29.85%). Speed: 1536.00 images/min. ETA: 29.56 minutes.
# Processed 19440/64728 images (30.03%). Speed: 1536.86 images/min. ETA: 29.47 minutes.
# Processed 19560/64728 images (30.22%). Speed: 1537.57 images/min. ETA: 29.38 minutes.
# Processed 19680/64728 images (30.40%). Speed: 1537.11 images/min. ETA: 29.31 minutes.
# Processed 19800/64728 images (30.59%). Speed: 1537.81 images/min. ETA: 29.22 minutes.
# Processed 19920/64728 images (30.77%). Speed: 1539.10 images/min. ETA: 29.11 minutes.
# Processed 20040/64728 images (30.96%). Speed: 1540.07 images/min. ETA: 29.02 minutes.
# Processed 20160/64728 images (31.15%). Speed: 1541.10 images/min. ETA: 28.92 minutes.
# Processed 20280/64728 images (31.33%). Speed: 1541.08 images/min. ETA: 28.84 minutes.
# Processed 20400/64728 images (31.52%). Speed: 1540.50 images/min. ETA: 28.78 minutes.
# Processed 20520/64728 images (31.70%). Speed: 1540.65 images/min. ETA: 28.69 minutes.
# Processed 20640/64728 images (31.89%). Speed: 1540.93 images/min. ETA: 28.61 minutes.
# Processed 20760/64728 images (32.07%). Speed: 1541.68 images/min. ETA: 28.52 minutes.
# Processed 20880/64728 images (32.26%). Speed: 1543.32 images/min. ETA: 28.41 minutes.
# Processed 21000/64728 images (32.44%). Speed: 1543.05 images/min. ETA: 28.34 minutes.
# Processed 21120/64728 images (32.63%). Speed: 1543.97 images/min. ETA: 28.24 minutes.
# Processed 21240/64728 images (32.81%). Speed: 1544.96 images/min. ETA: 28.15 minutes.
# Processed 21360/64728 images (33.00%). Speed: 1545.37 images/min. ETA: 28.06 minutes.
# Processed 21480/64728 images (33.19%). Speed: 1545.99 images/min. ETA: 27.97 minutes.
# Processed 21600/64728 images (33.37%). Speed: 1546.61 images/min. ETA: 27.89 minutes.
# Processed 21720/64728 images (33.56%). Speed: 1546.52 images/min. ETA: 27.81 minutes.
# Processed 21840/64728 images (33.74%). Speed: 1547.13 images/min. ETA: 27.72 minutes.
# Processed 21960/64728 images (33.93%). Speed: 1546.48 images/min. ETA: 27.66 minutes.
# Processed 22080/64728 images (34.11%). Speed: 1546.51 images/min. ETA: 27.58 minutes.
# Processed 22200/64728 images (34.30%). Speed: 1547.85 images/min. ETA: 27.48 minutes.
# Processed 22320/64728 images (34.48%). Speed: 1547.64 images/min. ETA: 27.40 minutes.
# Processed 22440/64728 images (34.67%). Speed: 1548.00 images/min. ETA: 27.32 minutes.
# Processed 22560/64728 images (34.85%). Speed: 1547.83 images/min. ETA: 27.24 minutes.
# Processed 22680/64728 images (35.04%). Speed: 1548.96 images/min. ETA: 27.15 minutes.
# Processed 22800/64728 images (35.22%). Speed: 1549.17 images/min. ETA: 27.06 minutes.
# Processed 22920/64728 images (35.41%). Speed: 1546.88 images/min. ETA: 27.03 minutes.
# Processed 23040/64728 images (35.60%). Speed: 1548.62 images/min. ETA: 26.92 minutes.
# Processed 23160/64728 images (35.78%). Speed: 1550.19 images/min. ETA: 26.81 minutes.
# Processed 23280/64728 images (35.97%). Speed: 1551.12 images/min. ETA: 26.72 minutes.
# Processed 23400/64728 images (36.15%). Speed: 1552.46 images/min. ETA: 26.62 minutes.
# Processed 23520/64728 images (36.34%). Speed: 1552.64 images/min. ETA: 26.54 minutes.
# Processed 23640/64728 images (36.52%). Speed: 1553.03 images/min. ETA: 26.46 minutes.
# Processed 23760/64728 images (36.71%). Speed: 1554.28 images/min. ETA: 26.36 minutes.
# Processed 23880/64728 images (36.89%). Speed: 1555.31 images/min. ETA: 26.26 minutes.
# Processed 24000/64728 images (37.08%). Speed: 1555.79 images/min. ETA: 26.18 minutes.
# Processed 24120/64728 images (37.26%). Speed: 1554.75 images/min. ETA: 26.12 minutes.
# Processed 24240/64728 images (37.45%). Speed: 1555.41 images/min. ETA: 26.03 minutes.
# Processed 24360/64728 images (37.63%). Speed: 1556.46 images/min. ETA: 25.94 minutes.
# Processed 24480/64728 images (37.82%). Speed: 1556.80 images/min. ETA: 25.85 minutes.
# Processed 24600/64728 images (38.01%). Speed: 1556.88 images/min. ETA: 25.77 minutes.
# Processed 24720/64728 images (38.19%). Speed: 1557.47 images/min. ETA: 25.69 minutes.
# Processed 24840/64728 images (38.38%). Speed: 1557.24 images/min. ETA: 25.61 minutes.
# Processed 24960/64728 images (38.56%). Speed: 1557.98 images/min. ETA: 25.53 minutes.
# Processed 25080/64728 images (38.75%). Speed: 1556.77 images/min. ETA: 25.47 minutes.
# Processed 25200/64728 images (38.93%). Speed: 1555.83 images/min. ETA: 25.41 minutes.
# Processed 25320/64728 images (39.12%). Speed: 1555.93 images/min. ETA: 25.33 minutes.
# Processed 25440/64728 images (39.30%). Speed: 1556.25 images/min. ETA: 25.25 minutes.
# Processed 25560/64728 images (39.49%). Speed: 1556.87 images/min. ETA: 25.16 minutes.
# Processed 25680/64728 images (39.67%). Speed: 1556.80 images/min. ETA: 25.08 minutes.
# Processed 25800/64728 images (39.86%). Speed: 1557.72 images/min. ETA: 24.99 minutes.
# Processed 25920/64728 images (40.04%). Speed: 1557.39 images/min. ETA: 24.92 minutes.
# Processed 26040/64728 images (40.23%). Speed: 1557.11 images/min. ETA: 24.85 minutes.
# Processed 26160/64728 images (40.42%). Speed: 1556.55 images/min. ETA: 24.78 minutes.
# Processed 26280/64728 images (40.60%). Speed: 1556.67 images/min. ETA: 24.70 minutes.
# Processed 30480/64728 images (47.09%). Speed: 1565.93 images/min. ETA: 21.87 minutes.
# Processed 30600/64728 images (47.27%). Speed: 1566.03 images/min. ETA: 21.79 minutes.
# Processed 30720/64728 images (47.46%). Speed: 1567.05 images/min. ETA: 21.70 minutes.
# Processed 30840/64728 images (47.65%). Speed: 1566.32 images/min. ETA: 21.64 minutes.
# Processed 30960/64728 images (47.83%). Speed: 1566.51 images/min. ETA: 21.56 minutes.
# Processed 31080/64728 images (48.02%). Speed: 1566.93 images/min. ETA: 21.47 minutes.
# Processed 31200/64728 images (48.20%). Speed: 1566.93 images/min. ETA: 21.40 minutes.
# Processed 31320/64728 images (48.39%). Speed: 1568.23 images/min. ETA: 21.30 minutes.
# Processed 31440/64728 images (48.57%). Speed: 1568.59 images/min. ETA: 21.22 minutes.
# Processed 31560/64728 images (48.76%). Speed: 1568.62 images/min. ETA: 21.14 minutes.
# Processed 31680/64728 images (48.94%). Speed: 1568.51 images/min. ETA: 21.07 minutes.
# Processed 31800/64728 images (49.13%). Speed: 1568.32 images/min. ETA: 21.00 minutes.
# Processed 31920/64728 images (49.31%). Speed: 1569.13 images/min. ETA: 20.91 minutes.
# Processed 32040/64728 images (49.50%). Speed: 1570.09 images/min. ETA: 20.82 minutes.
# Processed 32160/64728 images (49.68%). Speed: 1570.44 images/min. ETA: 20.74 minutes.
# Processed 32280/64728 images (49.87%). Speed: 1571.01 images/min. ETA: 20.65 minutes.
# Processed 32400/64728 images (50.06%). Speed: 1571.58 images/min. ETA: 20.57 minutes.
# Processed 32520/64728 images (50.24%). Speed: 1571.56 images/min. ETA: 20.49 minutes.
# Processed 32640/64728 images (50.43%). Speed: 1571.04 images/min. ETA: 20.42 minutes.
# Processed 32760/64728 images (50.61%). Speed: 1571.03 images/min. ETA: 20.35 minutes.
# Processed 32880/64728 images (50.80%). Speed: 1571.26 images/min. ETA: 20.27 minutes.
# Processed 33000/64728 images (50.98%). Speed: 1571.37 images/min. ETA: 20.19 minutes.
# Processed 33120/64728 images (51.17%). Speed: 1571.23 images/min. ETA: 20.12 minutes.
# Processed 33240/64728 images (51.35%). Speed: 1571.51 images/min. ETA: 20.04 minutes.
# Processed 33360/64728 images (51.54%). Speed: 1571.76 images/min. ETA: 19.96 minutes.
# Processed 33480/64728 images (51.72%). Speed: 1571.38 images/min. ETA: 19.89 minutes.
# Processed 33600/64728 images (51.91%). Speed: 1571.17 images/min. ETA: 19.81 minutes.
# Processed 33720/64728 images (52.09%). Speed: 1570.80 images/min. ETA: 19.74 minutes.
# Processed 33840/64728 images (52.28%). Speed: 1571.39 images/min. ETA: 19.66 minutes.
# Processed 33960/64728 images (52.47%). Speed: 1571.40 images/min. ETA: 19.58 minutes.
# Processed 34080/64728 images (52.65%). Speed: 1571.48 images/min. ETA: 19.50 minutes.
# Processed 34200/64728 images (52.84%). Speed: 1571.41 images/min. ETA: 19.43 minutes.
# Processed 34320/64728 images (53.02%). Speed: 1571.06 images/min. ETA: 19.36 minutes.
# Processed 34440/64728 images (53.21%). Speed: 1571.24 images/min. ETA: 19.28 minutes.
# Processed 34560/64728 images (53.39%). Speed: 1570.27 images/min. ETA: 19.21 minutes.
# Processed 34680/64728 images (53.58%). Speed: 1570.57 images/min. ETA: 19.13 minutes.
# Processed 34800/64728 images (53.76%). Speed: 1570.05 images/min. ETA: 19.06 minutes.
# Processed 34920/64728 images (53.95%). Speed: 1570.58 images/min. ETA: 18.98 minutes.
# Processed 35040/64728 images (54.13%). Speed: 1569.40 images/min. ETA: 18.92 minutes.
# Processed 35160/64728 images (54.32%). Speed: 1569.79 images/min. ETA: 18.84 minutes.
# Processed 35280/64728 images (54.51%). Speed: 1569.61 images/min. ETA: 18.76 minutes.
# Processed 35400/64728 images (54.69%). Speed: 1569.66 images/min. ETA: 18.68 minutes.
# Processed 35520/64728 images (54.88%). Speed: 1569.59 images/min. ETA: 18.61 minutes.
# Processed 35640/64728 images (55.06%). Speed: 1569.53 images/min. ETA: 18.53 minutes.
# Processed 35760/64728 images (55.25%). Speed: 1569.69 images/min. ETA: 18.45 minutes.
# Processed 35880/64728 images (55.43%). Speed: 1569.70 images/min. ETA: 18.38 minutes.
# Processed 36000/64728 images (55.62%). Speed: 1569.78 images/min. ETA: 18.30 minutes.
# Processed 36120/64728 images (55.80%). Speed: 1570.22 images/min. ETA: 18.22 minutes.
# Processed 36240/64728 images (55.99%). Speed: 1570.21 images/min. ETA: 18.14 minutes.
# Processed 36360/64728 images (56.17%). Speed: 1570.48 images/min. ETA: 18.06 minutes.
# Processed 36480/64728 images (56.36%). Speed: 1570.33 images/min. ETA: 17.99 minutes.
# Processed 36600/64728 images (56.54%). Speed: 1571.17 images/min. ETA: 17.90 minutes.
# Processed 36720/64728 images (56.73%). Speed: 1571.30 images/min. ETA: 17.82 minutes.
# Processed 36840/64728 images (56.92%). Speed: 1572.39 images/min. ETA: 17.74 minutes.
# Processed 36960/64728 images (57.10%). Speed: 1572.67 images/min. ETA: 17.66 minutes.
# Processed 37080/64728 images (57.29%). Speed: 1572.73 images/min. ETA: 17.58 minutes.
# Processed 37200/64728 images (57.47%). Speed: 1573.03 images/min. ETA: 17.50 minutes.
# Processed 37320/64728 images (57.66%). Speed: 1573.21 images/min. ETA: 17.42 minutes.
# Processed 37440/64728 images (57.84%). Speed: 1573.41 images/min. ETA: 17.34 minutes.
# Processed 37560/64728 images (58.03%). Speed: 1574.07 images/min. ETA: 17.26 minutes.
# Processed 37680/64728 images (58.21%). Speed: 1574.51 images/min. ETA: 17.18 minutes.
# Processed 37800/64728 images (58.40%). Speed: 1574.51 images/min. ETA: 17.10 minutes.
# Processed 37920/64728 images (58.58%). Speed: 1574.21 images/min. ETA: 17.03 minutes.
# Processed 38040/64728 images (58.77%). Speed: 1573.97 images/min. ETA: 16.96 minutes.
# Processed 38160/64728 images (58.95%). Speed: 1573.03 images/min. ETA: 16.89 minutes.
# Processed 38280/64728 images (59.14%). Speed: 1573.10 images/min. ETA: 16.81 minutes.
# Processed 38400/64728 images (59.33%). Speed: 1573.38 images/min. ETA: 16.73 minutes.
# Processed 38520/64728 images (59.51%). Speed: 1573.33 images/min. ETA: 16.66 minutes.
# Processed 38640/64728 images (59.70%). Speed: 1573.22 images/min. ETA: 16.58 minutes.
# Processed 46920/64728 images (72.49%). Speed: 1574.87 images/min. ETA: 11.31 minutes.
# Processed 47040/64728 images (72.67%). Speed: 1574.94 images/min. ETA: 11.23 minutes.
# Processed 47160/64728 images (72.86%). Speed: 1574.93 images/min. ETA: 11.15 minutes.
# Processed 47280/64728 images (73.04%). Speed: 1574.92 images/min. ETA: 11.08 minutes.
# Processed 47400/64728 images (73.23%). Speed: 1575.26 images/min. ETA: 11.00 minutes.
# Processed 47520/64728 images (73.41%). Speed: 1575.45 images/min. ETA: 10.92 minutes.
# Processed 47640/64728 images (73.60%). Speed: 1575.70 images/min. ETA: 10.84 minutes.
# Processed 47760/64728 images (73.79%). Speed: 1575.41 images/min. ETA: 10.77 minutes.
# Processed 47880/64728 images (73.97%). Speed: 1575.44 images/min. ETA: 10.69 minutes.
# Processed 48000/64728 images (74.16%). Speed: 1575.92 images/min. ETA: 10.61 minutes.
# Processed 48120/64728 images (74.34%). Speed: 1576.40 images/min. ETA: 10.54 minutes.
# Processed 48240/64728 images (74.53%). Speed: 1576.25 images/min. ETA: 10.46 minutes.
# Processed 48360/64728 images (74.71%). Speed: 1576.09 images/min. ETA: 10.39 minutes.
# Processed 48480/64728 images (74.90%). Speed: 1576.09 images/min. ETA: 10.31 minutes.
# Processed 48600/64728 images (75.08%). Speed: 1575.69 images/min. ETA: 10.24 minutes.
# Processed 48720/64728 images (75.27%). Speed: 1575.65 images/min. ETA: 10.16 minutes.
# Processed 48840/64728 images (75.45%). Speed: 1575.74 images/min. ETA: 10.08 minutes.
# Processed 48960/64728 images (75.64%). Speed: 1576.46 images/min. ETA: 10.00 minutes.
# Processed 49080/64728 images (75.82%). Speed: 1576.48 images/min. ETA: 9.93 minutes.
# Processed 49200/64728 images (76.01%). Speed: 1577.02 images/min. ETA: 9.85 minutes.
# Processed 49320/64728 images (76.20%). Speed: 1577.11 images/min. ETA: 9.77 minutes.
# Processed 49440/64728 images (76.38%). Speed: 1578.14 images/min. ETA: 9.69 minutes.
# Processed 49560/64728 images (76.57%). Speed: 1578.80 images/min. ETA: 9.61 minutes.
# Processed 49680/64728 images (76.75%). Speed: 1579.11 images/min. ETA: 9.53 minutes.
# Processed 49800/64728 images (76.94%). Speed: 1579.22 images/min. ETA: 9.45 minutes.
# Processed 49920/64728 images (77.12%). Speed: 1579.54 images/min. ETA: 9.37 minutes.
# Processed 50040/64728 images (77.31%). Speed: 1578.96 images/min. ETA: 9.30 minutes.
# Processed 50160/64728 images (77.49%). Speed: 1579.25 images/min. ETA: 9.22 minutes.
# Processed 50280/64728 images (77.68%). Speed: 1579.55 images/min. ETA: 9.15 minutes.
# Processed 50400/64728 images (77.86%). Speed: 1579.58 images/min. ETA: 9.07 minutes.
# Processed 50520/64728 images (78.05%). Speed: 1579.93 images/min. ETA: 8.99 minutes.
# Processed 50640/64728 images (78.24%). Speed: 1580.22 images/min. ETA: 8.92 minutes.
# Processed 50760/64728 images (78.42%). Speed: 1580.20 images/min. ETA: 8.84 minutes.
# Processed 50880/64728 images (78.61%). Speed: 1580.37 images/min. ETA: 8.76 minutes.
# Processed 51000/64728 images (78.79%). Speed: 1579.62 images/min. ETA: 8.69 minutes.
# Processed 51120/64728 images (78.98%). Speed: 1579.80 images/min. ETA: 8.61 minutes.
# Processed 51240/64728 images (79.16%). Speed: 1580.02 images/min. ETA: 8.54 minutes.
# Processed 51360/64728 images (79.35%). Speed: 1580.25 images/min. ETA: 8.46 minutes.
# Processed 51480/64728 images (79.53%). Speed: 1580.55 images/min. ETA: 8.38 minutes.
# Processed 51600/64728 images (79.72%). Speed: 1581.06 images/min. ETA: 8.30 minutes.
# Processed 51720/64728 images (79.90%). Speed: 1581.34 images/min. ETA: 8.23 minutes.
# Processed 51840/64728 images (80.09%). Speed: 1581.37 images/min. ETA: 8.15 minutes.
# Processed 51960/64728 images (80.27%). Speed: 1581.91 images/min. ETA: 8.07 minutes.
# Processed 52080/64728 images (80.46%). Speed: 1582.62 images/min. ETA: 7.99 minutes.
# Processed 52200/64728 images (80.65%). Speed: 1582.69 images/min. ETA: 7.92 minutes.
# Processed 52320/64728 images (80.83%). Speed: 1582.53 images/min. ETA: 7.84 minutes.
# Processed 52440/64728 images (81.02%). Speed: 1582.66 images/min. ETA: 7.76 minutes.
# Processed 52560/64728 images (81.20%). Speed: 1582.57 images/min. ETA: 7.69 minutes.
# Processed 52680/64728 images (81.39%). Speed: 1583.07 images/min. ETA: 7.61 minutes.
# Processed 52800/64728 images (81.57%). Speed: 1582.93 images/min. ETA: 7.54 minutes.
# Processed 52920/64728 images (81.76%). Speed: 1583.37 images/min. ETA: 7.46 minutes.
# Processed 53040/64728 images (81.94%). Speed: 1583.86 images/min. ETA: 7.38 minutes.
# Processed 53160/64728 images (82.13%). Speed: 1582.32 images/min. ETA: 7.31 minutes.
# Processed 53280/64728 images (82.31%). Speed: 1582.85 images/min. ETA: 7.23 minutes.
# Processed 53400/64728 images (82.50%). Speed: 1583.29 images/min. ETA: 7.15 minutes.
# Processed 53520/64728 images (82.68%). Speed: 1583.58 images/min. ETA: 7.08 minutes.
# Processed 53640/64728 images (82.87%). Speed: 1583.88 images/min. ETA: 7.00 minutes.
# Processed 53760/64728 images (83.06%). Speed: 1584.41 images/min. ETA: 6.92 minutes.
# Processed 53880/64728 images (83.24%). Speed: 1584.26 images/min. ETA: 6.85 minutes.
# Processed 54000/64728 images (83.43%). Speed: 1584.54 images/min. ETA: 6.77 minutes.
# Processed 54120/64728 images (83.61%). Speed: 1584.20 images/min. ETA: 6.70 minutes.
# Processed 54240/64728 images (83.80%). Speed: 1584.32 images/min. ETA: 6.62 minutes.
# Processed 54360/64728 images (83.98%). Speed: 1584.26 images/min. ETA: 6.54 minutes.
# Processed 54480/64728 images (84.17%). Speed: 1584.21 images/min. ETA: 6.47 minutes.
# Processed 54600/64728 images (84.35%). Speed: 1584.51 images/min. ETA: 6.39 minutes.
# Processed 54720/64728 images (84.54%). Speed: 1584.98 images/min. ETA: 6.31 minutes.
# Processed 54840/64728 images (84.72%). Speed: 1585.62 images/min. ETA: 6.24 minutes.
# Processed 54960/64728 images (84.91%). Speed: 1585.64 images/min. ETA: 6.16 minutes.
# Processed 55080/64728 images (85.09%). Speed: 1585.44 images/min. ETA: 6.09 minutes.
# Processed 55200/64728 images (85.28%). Speed: 1585.81 images/min. ETA: 6.01 minutes.
# Processed 55320/64728 images (85.47%). Speed: 1585.40 images/min. ETA: 5.93 minutes.
# Processed 55440/64728 images (85.65%). Speed: 1585.98 images/min. ETA: 5.86 minutes.
# Processed 55560/64728 images (85.84%). Speed: 1586.06 images/min. ETA: 5.78 minutes.
# Processed 55680/64728 images (86.02%). Speed: 1586.11 images/min. ETA: 5.70 minutes.
# Processed 55800/64728 images (86.21%). Speed: 1585.66 images/min. ETA: 5.63 minutes.
# Processed 55920/64728 images (86.39%). Speed: 1585.02 images/min. ETA: 5.56 minutes.
# Processed 56040/64728 images (86.58%). Speed: 1585.46 images/min. ETA: 5.48 minutes.
# Processed 56160/64728 images (86.76%). Speed: 1585.39 images/min. ETA: 5.40 minutes.
# Processed 56280/64728 images (86.95%). Speed: 1585.42 images/min. ETA: 5.33 minutes.
# Processed 56400/64728 images (87.13%). Speed: 1585.46 images/min. ETA: 5.25 minutes.
# Processed 56520/64728 images (87.32%). Speed: 1585.67 images/min. ETA: 5.18 minutes.
# Processed 56640/64728 images (87.50%). Speed: 1586.23 images/min. ETA: 5.10 minutes.
# Processed 56760/64728 images (87.69%). Speed: 1586.55 images/min. ETA: 5.02 minutes.
# Processed 56880/64728 images (87.88%). Speed: 1586.65 images/min. ETA: 4.95 minutes.
# Processed 57000/64728 images (88.06%). Speed: 1587.38 images/min. ETA: 4.87 minutes.
# Processed 57120/64728 images (88.25%). Speed: 1587.43 images/min. ETA: 4.79 minutes.
# Processed 57240/64728 images (88.43%). Speed: 1587.32 images/min. ETA: 4.72 minutes.
# Processed 57360/64728 images (88.62%). Speed: 1587.55 images/min. ETA: 4.64 minutes.
# Processed 57480/64728 images (88.80%). Speed: 1587.74 images/min. ETA: 4.56 minutes.
# Processed 57600/64728 images (88.99%). Speed: 1587.59 images/min. ETA: 4.49 minutes.
# Processed 57720/64728 images (89.17%). Speed: 1588.11 images/min. ETA: 4.41 minutes.
# Processed 57840/64728 images (89.36%). Speed: 1588.53 images/min. ETA: 4.34 minutes.
# Processed 57960/64728 images (89.54%). Speed: 1588.72 images/min. ETA: 4.26 minutes.
# Processed 58080/64728 images (89.73%). Speed: 1588.65 images/min. ETA: 4.18 minutes.
# Processed 58200/64728 images (89.91%). Speed: 1588.35 images/min. ETA: 4.11 minutes.
# Processed 58320/64728 images (90.10%). Speed: 1588.22 images/min. ETA: 4.03 minutes.
# Processed 58440/64728 images (90.29%). Speed: 1588.71 images/min. ETA: 3.96 minutes.
# Processed 58560/64728 images (90.47%). Speed: 1588.76 images/min. ETA: 3.88 minutes.
# Processed 58680/64728 images (90.66%). Speed: 1588.97 images/min. ETA: 3.81 minutes.
# Processed 58800/64728 images (90.84%). Speed: 1589.50 images/min. ETA: 3.73 minutes.
# Processed 58920/64728 images (91.03%). Speed: 1589.94 images/min. ETA: 3.65 minutes.
# Processed 59040/64728 images (91.21%). Speed: 1589.79 images/min. ETA: 3.58 minutes.
# Processed 59160/64728 images (91.40%). Speed: 1590.01 images/min. ETA: 3.50 minutes.
# Processed 59280/64728 images (91.58%). Speed: 1590.30 images/min. ETA: 3.43 minutes.
# Processed 59400/64728 images (91.77%). Speed: 1590.82 images/min. ETA: 3.35 minutes.
# Processed 59520/64728 images (91.95%). Speed: 1590.94 images/min. ETA: 3.27 minutes.
# Processed 59640/64728 images (92.14%). Speed: 1591.04 images/min. ETA: 3.20 minutes.
# Processed 59760/64728 images (92.32%). Speed: 1591.22 images/min. ETA: 3.12 minutes.
# Processed 59880/64728 images (92.51%). Speed: 1591.71 images/min. ETA: 3.05 minutes.
# Processed 60000/64728 images (92.70%). Speed: 1591.89 images/min. ETA: 2.97 minutes.
# Processed 60120/64728 images (92.88%). Speed: 1592.43 images/min. ETA: 2.89 minutes.
# Processed 60240/64728 images (93.07%). Speed: 1592.51 images/min. ETA: 2.82 minutes.
# Processed 60360/64728 images (93.25%). Speed: 1592.82 images/min. ETA: 2.74 minutes.
# Processed 60480/64728 images (93.44%). Speed: 1593.25 images/min. ETA: 2.67 minutes.
# Processed 60600/64728 images (93.62%). Speed: 1592.93 images/min. ETA: 2.59 minutes.
# Processed 60720/64728 images (93.81%). Speed: 1592.87 images/min. ETA: 2.52 minutes.
# Processed 60840/64728 images (93.99%). Speed: 1593.40 images/min. ETA: 2.44 minutes.
# Processed 60960/64728 images (94.18%). Speed: 1593.90 images/min. ETA: 2.36 minutes.
# Processed 61080/64728 images (94.36%). Speed: 1593.85 images/min. ETA: 2.29 minutes.
# Processed 61200/64728 images (94.55%). Speed: 1594.13 images/min. ETA: 2.21 minutes.
# Processed 61320/64728 images (94.73%). Speed: 1594.38 images/min. ETA: 2.14 minutes.
# Processed 61440/64728 images (94.92%). Speed: 1594.03 images/min. ETA: 2.06 minutes.
# Processed 61560/64728 images (95.11%). Speed: 1594.06 images/min. ETA: 1.99 minutes.
# Processed 61680/64728 images (95.29%). Speed: 1594.29 images/min. ETA: 1.91 minutes.
# Processed 61800/64728 images (95.48%). Speed: 1594.22 images/min. ETA: 1.84 minutes.
# Processed 61920/64728 images (95.66%). Speed: 1594.45 images/min. ETA: 1.76 minutes.
# Processed 62040/64728 images (95.85%). Speed: 1594.22 images/min. ETA: 1.69 minutes.
# Processed 62160/64728 images (96.03%). Speed: 1594.45 images/min. ETA: 1.61 minutes.
# Processed 62280/64728 images (96.22%). Speed: 1594.37 images/min. ETA: 1.54 minutes.
# Processed 62400/64728 images (96.40%). Speed: 1594.69 images/min. ETA: 1.46 minutes.
# Processed 62520/64728 images (96.59%). Speed: 1594.75 images/min. ETA: 1.38 minutes.
# Processed 62640/64728 images (96.77%). Speed: 1595.11 images/min. ETA: 1.31 minutes.
# Processed 62760/64728 images (96.96%). Speed: 1595.69 images/min. ETA: 1.23 minutes.
# Processed 62880/64728 images (97.14%). Speed: 1596.21 images/min. ETA: 1.16 minutes.
# Processed 63000/64728 images (97.33%). Speed: 1596.63 images/min. ETA: 1.08 minutes.
# Processed 63120/64728 images (97.52%). Speed: 1597.10 images/min. ETA: 1.01 minutes.
# Processed 63240/64728 images (97.70%). Speed: 1597.26 images/min. ETA: 0.93 minutes.
# Processed 63360/64728 images (97.89%). Speed: 1597.24 images/min. ETA: 0.86 minutes.
# Processed 63480/64728 images (98.07%). Speed: 1597.51 images/min. ETA: 0.78 minutes.
# Processed 63600/64728 images (98.26%). Speed: 1598.14 images/min. ETA: 0.71 minutes.
# Processed 63720/64728 images (98.44%). Speed: 1598.25 images/min. ETA: 0.63 minutes.
# Processed 63840/64728 images (98.63%). Speed: 1598.62 images/min. ETA: 0.56 minutes.
# Processed 63960/64728 images (98.81%). Speed: 1598.54 images/min. ETA: 0.48 minutes.
# Processed 64080/64728 images (99.00%). Speed: 1598.17 images/min. ETA: 0.41 minutes.
# Processed 64200/64728 images (99.18%). Speed: 1598.41 images/min. ETA: 0.33 minutes.
# Processed 64320/64728 images (99.37%). Speed: 1598.24 images/min. ETA: 0.26 minutes.
# Processed 64440/64728 images (99.56%). Speed: 1598.02 images/min. ETA: 0.18 minutes.
# Processed 64560/64728 images (99.74%). Speed: 1597.90 images/min. ETA: 0.11 minutes.
# Processed 64680/64728 images (99.93%). Speed: 1598.23 images/min. ETA: 0.03 minutes.
# Processed 64728/64728 images (100.00%). Speed: 1598.38 images/min. ETA: 0.00 minutes.

# %%
# import os
# import json
# import torch
# from torchvision.models.detection import maskrcnn_resnet50_fpn
# from torchvision.transforms import functional as F
# from PIL import Image
# import numpy as np
# from time import time
# from torch.cuda.amp import autocast
# from torch.utils.data import DataLoader, Dataset

# # Check for GPU availability
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"Using device: {device}")

# # Load the pretrained Mask R-CNN model
# model = maskrcnn_resnet50_fpn(pretrained=True)
# model = model.to(device)  # Move the model to GPU
# model.eval()  # Set the model to evaluation mode


# def save_image_paths_to_json(input_dir, json_path):
#     """
#     Traverse the input directory and save all image paths to a JSON file.
#     """
#     all_images = []
#     for root, _, files in os.walk(input_dir):
#         for file in sorted(files):  # Ensure consistent order
#             if file.lower().endswith((".jpg", ".jpeg", ".png")):
#                 all_images.append(os.path.join(root, file))
#     with open(json_path, 'w') as json_file:
#         json.dump(all_images, json_file)
#     print(f"Saved {len(all_images)} image paths to {json_path}")


# def load_image_paths_from_json(json_path):
#     """
#     Load image paths from a JSON file.
#     """
#     if not os.path.exists(json_path):
#         raise FileNotFoundError(f"JSON file not found: {json_path}")
#     with open(json_path, 'r') as json_file:
#         all_images = json.load(json_file)
#     print(f"Loaded {len(all_images)} image paths from {json_path}")
#     return all_images


# def filter_images_by_directory(image_paths):
#     """
#     Return all image paths without filtering.
#     """
#     return image_paths  # No filtering, return all image paths


# def mask_humans(image, predictions, threshold=0.5, original_size=None):
#     """
#     Mask human figures in the input image and restore to original size if specified.
#     """
#     image_array = np.array(image)
#     masks = predictions['masks']
#     labels = predictions['labels']
#     scores = predictions['scores']

#     for i in range(len(masks)):
#         if labels[i] == 1 and scores[i] > threshold:  # Label 1 in COCO is "person"
#             binary_mask = masks[i, 0].cpu().numpy() > 0.5
#             binary_mask = Image.fromarray(binary_mask).resize(
#                 (image_array.shape[1], image_array.shape[0]), Image.NEAREST
#             )
#             binary_mask = np.array(binary_mask)
#             image_array[binary_mask] = [255, 255, 255]

#     masked_image = Image.fromarray(image_array)
#     if original_size:
#         masked_image = masked_image.resize(original_size, Image.ANTIALIAS)
#     return masked_image


# class ImageDataset(Dataset):
#     """
#     Custom Dataset for loading images and resizing.
#     """
#     def __init__(self, image_paths, resize_to):
#         self.image_paths = image_paths
#         self.resize_to = resize_to

#     def __len__(self):
#         return len(self.image_paths)

#     def __getitem__(self, idx):
#         path = self.image_paths[idx]
#         try:
#             image = Image.open(path).convert("RGB")
#             original_size = image.size
#             image_resized = image.resize((self.resize_to, self.resize_to), Image.ANTIALIAS)
#             return F.to_tensor(image_resized), original_size, path
#         except Exception as e:
#             print(f"Error loading image: {path}, skipping. Error: {e}")
#             return None


# def custom_collate_fn(batch):
#     """
#     Custom collate function to handle None values in DataLoader.
#     """
#     batch = [item for item in batch if item is not None]  # Filter out None values
#     images, original_sizes, paths = zip(*batch)
#     return torch.stack(images), original_sizes, paths


# def process_and_mask_images(input_dir, json_path, output_dir, batch_size=4, threshold=0.5, resize_to=800, num_workers=4):
#     """
#     Process images using CPU for preprocessing and GPU for inference.
#     """
#     if not os.path.exists(json_path):
#         save_image_paths_to_json(input_dir, json_path)
    
#     all_images = load_image_paths_from_json(json_path)
#     filtered_images = filter_images_by_directory(all_images)
#     dataset = ImageDataset(filtered_images, resize_to)
#     dataloader = DataLoader(
#         dataset,
#         batch_size=batch_size,
#         num_workers=num_workers,  # Use multiple CPU workers for preprocessing
#         pin_memory=True,
#         collate_fn=custom_collate_fn
#     )

#     start_time = time()
#     processed_images = 0
#     total_images = len(filtered_images)

#     for images, original_sizes, paths in dataloader:
#         images = images.to(device)  # Move batch to GPU
#         with autocast():  # Mixed precision inference
#             with torch.no_grad():
#                 predictions = model(images)

#         for path, preds, original_size in zip(paths, predictions, original_sizes):
#             original_image = Image.open(path).convert("RGB")
#             masked_image = mask_humans(original_image, preds, threshold, original_size=original_size)

#             relative_path = os.path.relpath(path, input_dir)
#             output_path = os.path.join(output_dir, relative_path)
#             os.makedirs(os.path.dirname(output_path), exist_ok=True)
#             masked_image.save(output_path)

#         processed_images += len(paths)
#         elapsed_time = time() - start_time
#         images_per_minute = (processed_images / elapsed_time) * 60
#         remaining_images = total_images - processed_images
#         eta = remaining_images / images_per_minute

#         print(
#             f"Processed {processed_images}/{total_images} images "
#             f"({(processed_images / total_images) * 100:.2f}%). "
#             f"Speed: {images_per_minute:.2f} images/min. ETA: {eta:.2f} minutes."
#         )
#     torch.cuda.empty_cache()


# # Set paths for input, output, and JSON
# input_directory = "/scratch/supalami/ProjectDataSplitwise/extracted_frames_mk_val_videos"
# json_file_path = "/scratch/supalami/ProjectDataSplitwise/image_paths_validation.json"
# output_directory = "/scratch/supalami/ProjectDataSplitwise/masked_extracted_frames_validation"

# # Process and mask images using GPU for inference and CPU for preprocessing
# process_and_mask_images(
#     input_directory,
#     json_file_path,
#     output_directory,
#     batch_size=120,
#     threshold=0.5,
#     resize_to=256,
#     num_workers=os.cpu_count()  # Use all available CPU cores
# )

# %%
# # Clear unused variables
# import gc
# gc.collect()
# torch.cuda.empty_cache()
